# %%
import pandas as pd
import chardet
import re

# %% [markdown]
# #### Create functions to normalize zip codes if any are greater than or less than 5 digits

# %%
def first_five(s):
    return s[0:5]

# def pad_tony(s):
#     zip_len = len(s)
#     if s == 3 or s == 7:
#         padded_s = "00" + s
#     elif s == 4 or s == 8:
#         padded_s = "0" + s
#     else:
#         padded_s = s
#     return padded_s

def pad_rjust(s):
    zip_len = len(s)
    if zip_len <= 5:
        final_len = 5
    else:
        final_len = 9
    padded_s = s.rjust(final_len, "0")
    return padded_s

def normalize_zip(s):
    padded_zip = pad_rjust(s)
    stripped_zip = first_five(padded_zip)
    return stripped_zip

# %% [markdown]
# ### County & Per Capita Income (2020)

# %%
# Link as reference
# https://apps.bea.gov/iTable/iTable.cfm?reqid=70&step=30&isuri=1&major_area=4&area=xx&year=2020&tableid=20&category=720&area_type=4&year_end=-1&classification=non-industry&state=xx&statistic=3&yearbegin=-1&unit_of_measure=levels

# %%
# NOTE: Skip rows needed to remove header info.  Error occurs otherwise.
# Create DataFrame for county and per capita personal income

bea_income_original_df = pd.read_csv("Resources/bea_income_2020.csv", skiprows=4)
bea_income_original_df
# Out:
#                                                 GeoFips      GeoName   2020
# 0                                                 01001  Autauga, AL  46814
# 1                                                 01003  Baldwin, AL  50953
# 2                                                 01005  Barbour, AL  37850
# 3                                                 01007     Bibb, AL  34300
# 4                                                 01009   Blount, AL  38808
# ...                                                 ...          ...    ...
# 3154  * Shawano, WI and Menominee, WI are combined a...          NaN    NaN
# 3155  Metropolitan Areas are defined (geographically...          NaN    NaN
# 3156  Note. All dollar estimates are in thousands of...          NaN    NaN
# 3157                                (NA) Not available.          NaN    NaN
# 3158  Last updated: November 16, 2021-- new statisti...          NaN    NaN
#
# [3159 rows x 3 columns]

# %%
# Check footer info
bea_income_original_df.tail(20)
# Out:
#                                                 GeoFips     GeoName   2020
# 3139                                              56045  Weston, WY  47599
# 3140                                Legend / Footnotes:         NaN    NaN
# 3141  2/ Per capita personal income was computed usi...         NaN    NaN
# 3142  * Estimates for 1979 forward reflect Alaska Ce...         NaN    NaN
# 3143  * Estimates from 1988 forward separate Aleutia...         NaN    NaN
# 3144  * Estimates for 1991 forward separate Denali B...         NaN    NaN
# 3145  * Estimates from 1993 forward separate Skagway...         NaN    NaN
# 3146  * Wade Hampton Census Area was renamed Kusilva...         NaN    NaN
# 3147  * On January 2, 2019, two new county equivalen...         NaN    NaN
# 3148  * La Paz County, AZ was separated from Yuma Co...         NaN    NaN
# 3149  * Broomfield County, CO, was created from part...         NaN    NaN
# 3150  * Kalawao County, Hawaii is combined with Maui...         NaN    NaN
# 3151  * Cibola, NM was separated from Valencia in Ju...         NaN    NaN
# 3152  * Shannon County, SD was renamed to Oglala Lak...         NaN    NaN
# 3153  * Virginia combination areas consist of one or...         NaN    NaN
# 3154  * Shawano, WI and Menominee, WI are combined a...         NaN    NaN
# 3155  Metropolitan Areas are defined (geographically...         NaN    NaN
# 3156  Note. All dollar estimates are in thousands of...         NaN    NaN
# 3157                                (NA) Not available.         NaN    NaN
# 3158  Last updated: November 16, 2021-- new statisti...         NaN    NaN

# %%
# Use NAN in last two columns to find where to remove footer rows
both_columns_null_idx = bea_income_original_df[["GeoName", "2020"]].isna().all(axis="columns")
both_columns_null_idx
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3154     True
# 3155     True
# 3156     True
# 3157     True
# 3158     True
# Length: 3159, dtype: bool

# %%
# Use NAN in last two columns to find where to remove footer rows
bea_income_original_df.loc[both_columns_null_idx]
# Out:
#                                                 GeoFips GeoName 2020
# 3140                                Legend / Footnotes:     NaN  NaN
# 3141  2/ Per capita personal income was computed usi...     NaN  NaN
# 3142  * Estimates for 1979 forward reflect Alaska Ce...     NaN  NaN
# 3143  * Estimates from 1988 forward separate Aleutia...     NaN  NaN
# 3144  * Estimates for 1991 forward separate Denali B...     NaN  NaN
# 3145  * Estimates from 1993 forward separate Skagway...     NaN  NaN
# 3146  * Wade Hampton Census Area was renamed Kusilva...     NaN  NaN
# 3147  * On January 2, 2019, two new county equivalen...     NaN  NaN
# 3148  * La Paz County, AZ was separated from Yuma Co...     NaN  NaN
# 3149  * Broomfield County, CO, was created from part...     NaN  NaN
# 3150  * Kalawao County, Hawaii is combined with Maui...     NaN  NaN
# 3151  * Cibola, NM was separated from Valencia in Ju...     NaN  NaN
# 3152  * Shannon County, SD was renamed to Oglala Lak...     NaN  NaN
# 3153  * Virginia combination areas consist of one or...     NaN  NaN
# 3154  * Shawano, WI and Menominee, WI are combined a...     NaN  NaN
# 3155  Metropolitan Areas are defined (geographically...     NaN  NaN
# 3156  Note. All dollar estimates are in thousands of...     NaN  NaN
# 3157                                (NA) Not available.     NaN  NaN
# 3158  Last updated: November 16, 2021-- new statisti...     NaN  NaN

# %%
# Drop footer rows
bea_income_original_df.drop(bea_income_original_df.tail(19).index, inplace = True)
bea_income_original_df
# Out:
#      GeoFips         GeoName    2020
# 0      01001     Autauga, AL   46814
# 1      01003     Baldwin, AL   50953
# 2      01005     Barbour, AL   37850
# 3      01007        Bibb, AL   34300
# 4      01009      Blount, AL   38808
# ...      ...             ...     ...
# 3135   56037  Sweetwater, WY   54000
# 3136   56039       Teton, WY  220645
# 3137   56041       Uinta, WY   42854
# 3138   56043    Washakie, WY   54361
# 3139   56045      Weston, WY   47599
#
# [3140 rows x 3 columns]

# %%
# Rename columnns
bea_income_original_df = bea_income_original_df.rename(columns={"2020": "per_capita_income"})
bea_income_original_df
# Out:
#      GeoFips         GeoName per_capita_income
# 0      01001     Autauga, AL             46814
# 1      01003     Baldwin, AL             50953
# 2      01005     Barbour, AL             37850
# 3      01007        Bibb, AL             34300
# 4      01009      Blount, AL             38808
# ...      ...             ...               ...
# 3135   56037  Sweetwater, WY             54000
# 3136   56039       Teton, WY            220645
# 3137   56041       Uinta, WY             42854
# 3138   56043    Washakie, WY             54361
# 3139   56045      Weston, WY             47599
#
# [3140 rows x 3 columns]

# %%
# Check dtypes
bea_income_original_df.dtypes
# Out:
# GeoFips              object
# GeoName              object
# per_capita_income    object
# dtype: object

# %% [markdown]
# ### County & Population (2020)

# %%
# Link as reference
# https://apps.bea.gov/iTable/iTable.cfm?reqid=70&step=30&isuri=1&major_area=4&area=xx&year=2020&tableid=20&category=720&area_type=4&year_end=-1&classification=non-industry&state=xx&statistic=2&yearbegin=-1&unit_of_measure=levels

# %%
# NOTE: Skip rows needed to remove header info.  Error occurs otherwise.
# Create DataFrame for county and population

bea_population_original_df = pd.read_csv("Resources/bea_population_2020.csv", skiprows=4)
bea_population_original_df
# Out:
#                                                 GeoFips      GeoName    2020
# 0                                                 01001  Autauga, AL   56145
# 1                                                 01003  Baldwin, AL  229287
# 2                                                 01005  Barbour, AL   24589
# 3                                                 01007     Bibb, AL   22136
# 4                                                 01009   Blount, AL   57879
# ...                                                 ...          ...     ...
# 3154  * Shawano, WI and Menominee, WI are combined a...          NaN     NaN
# 3155  Metropolitan Areas are defined (geographically...          NaN     NaN
# 3156  Note. All dollar estimates are in thousands of...          NaN     NaN
# 3157                                (NA) Not available.          NaN     NaN
# 3158  Last updated: November 16, 2021-- new statisti...          NaN     NaN
#
# [3159 rows x 3 columns]

# %%
# Check footer info
bea_population_original_df.tail(20)
# Out:
#                                                 GeoFips     GeoName  2020
# 3139                                              56045  Weston, WY  6743
# 3140                                Legend / Footnotes:         NaN   NaN
# 3141  1/ Census Bureau midyear population estimates....         NaN   NaN
# 3142  * Estimates for 1979 forward reflect Alaska Ce...         NaN   NaN
# 3143  * Estimates from 1988 forward separate Aleutia...         NaN   NaN
# 3144  * Estimates for 1991 forward separate Denali B...         NaN   NaN
# 3145  * Estimates from 1993 forward separate Skagway...         NaN   NaN
# 3146  * Wade Hampton Census Area was renamed Kusilva...         NaN   NaN
# 3147  * On January 2, 2019, two new county equivalen...         NaN   NaN
# 3148  * La Paz County, AZ was separated from Yuma Co...         NaN   NaN
# 3149  * Broomfield County, CO, was created from part...         NaN   NaN
# 3150  * Kalawao County, Hawaii is combined with Maui...         NaN   NaN
# 3151  * Cibola, NM was separated from Valencia in Ju...         NaN   NaN
# 3152  * Shannon County, SD was renamed to Oglala Lak...         NaN   NaN
# 3153  * Virginia combination areas consist of one or...         NaN   NaN
# 3154  * Shawano, WI and Menominee, WI are combined a...         NaN   NaN
# 3155  Metropolitan Areas are defined (geographically...         NaN   NaN
# 3156  Note. All dollar estimates are in thousands of...         NaN   NaN
# 3157                                (NA) Not available.         NaN   NaN
# 3158  Last updated: November 16, 2021-- new statisti...         NaN   NaN

# %%
# Use NAN in last two columns to find where to remove footer rows
both_columns_null_idx = bea_population_original_df[["GeoName", "2020"]].isna().all(axis="columns")
both_columns_null_idx
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3154     True
# 3155     True
# 3156     True
# 3157     True
# 3158     True
# Length: 3159, dtype: bool

# %%
# Use NAN in last two columns to find where to remove footer rows
bea_population_original_df.loc[both_columns_null_idx]
# Out:
#                                                 GeoFips GeoName 2020
# 3140                                Legend / Footnotes:     NaN  NaN
# 3141  1/ Census Bureau midyear population estimates....     NaN  NaN
# 3142  * Estimates for 1979 forward reflect Alaska Ce...     NaN  NaN
# 3143  * Estimates from 1988 forward separate Aleutia...     NaN  NaN
# 3144  * Estimates for 1991 forward separate Denali B...     NaN  NaN
# 3145  * Estimates from 1993 forward separate Skagway...     NaN  NaN
# 3146  * Wade Hampton Census Area was renamed Kusilva...     NaN  NaN
# 3147  * On January 2, 2019, two new county equivalen...     NaN  NaN
# 3148  * La Paz County, AZ was separated from Yuma Co...     NaN  NaN
# 3149  * Broomfield County, CO, was created from part...     NaN  NaN
# 3150  * Kalawao County, Hawaii is combined with Maui...     NaN  NaN
# 3151  * Cibola, NM was separated from Valencia in Ju...     NaN  NaN
# 3152  * Shannon County, SD was renamed to Oglala Lak...     NaN  NaN
# 3153  * Virginia combination areas consist of one or...     NaN  NaN
# 3154  * Shawano, WI and Menominee, WI are combined a...     NaN  NaN
# 3155  Metropolitan Areas are defined (geographically...     NaN  NaN
# 3156  Note. All dollar estimates are in thousands of...     NaN  NaN
# 3157                                (NA) Not available.     NaN  NaN
# 3158  Last updated: November 16, 2021-- new statisti...     NaN  NaN

# %%
# Drop footer rows
bea_population_original_df.drop(bea_population_original_df.tail(19).index, inplace = True)
bea_population_original_df
# Out:
#      GeoFips         GeoName    2020
# 0      01001     Autauga, AL   56145
# 1      01003     Baldwin, AL  229287
# 2      01005     Barbour, AL   24589
# 3      01007        Bibb, AL   22136
# 4      01009      Blount, AL   57879
# ...      ...             ...     ...
# 3135   56037  Sweetwater, WY   42673
# 3136   56039       Teton, WY   23497
# 3137   56041       Uinta, WY   20215
# 3138   56043    Washakie, WY    7760
# 3139   56045      Weston, WY    6743
#
# [3140 rows x 3 columns]

# %%
# Rename columnns
bea_population_original_df = bea_population_original_df.rename(columns={"2020": "population"})
bea_population_original_df
# Out:
#      GeoFips         GeoName population
# 0      01001     Autauga, AL      56145
# 1      01003     Baldwin, AL     229287
# 2      01005     Barbour, AL      24589
# 3      01007        Bibb, AL      22136
# 4      01009      Blount, AL      57879
# ...      ...             ...        ...
# 3135   56037  Sweetwater, WY      42673
# 3136   56039       Teton, WY      23497
# 3137   56041       Uinta, WY      20215
# 3138   56043    Washakie, WY       7760
# 3139   56045      Weston, WY       6743
#
# [3140 rows x 3 columns]

# %%
# Check dtypes
bea_population_original_df.dtypes
# Out:
# GeoFips       object
# GeoName       object
# population    object
# dtype: object

# %% [markdown]
# ### Merge income & population

# %%
# Merge bea dataframes (income and popuation)
bea_merge_df = bea_income_original_df.merge(bea_population_original_df, left_on="GeoFips", right_on="GeoFips")
bea_merge_df
# Out:
#      GeoFips       GeoName_x per_capita_income       GeoName_y population
# 0      01001     Autauga, AL             46814     Autauga, AL      56145
# 1      01003     Baldwin, AL             50953     Baldwin, AL     229287
# 2      01005     Barbour, AL             37850     Barbour, AL      24589
# 3      01007        Bibb, AL             34300        Bibb, AL      22136
# 4      01009      Blount, AL             38808      Blount, AL      57879
# ...      ...             ...               ...             ...        ...
# 3135   56037  Sweetwater, WY             54000  Sweetwater, WY      42673
# 3136   56039       Teton, WY            220645       Teton, WY      23497
# 3137   56041       Uinta, WY             42854       Uinta, WY      20215
# 3138   56043    Washakie, WY             54361    Washakie, WY       7760
# 3139   56045      Weston, WY             47599      Weston, WY       6743
#
# [3140 rows x 5 columns]

# %%
# Saving file as reference
bea_merge_df.to_csv("Resources/bea_merge_df.csv")

# %%
# Confirm that geonames match after merge
# geoname_mismatch_idx = bea_merge_df["GeoName_x"] != bea_merge_df["GeoName_y"]
# sum(geoname_mismatch_idx)

# %%
# Confirm that geonames match after merge
# bea_merge_df.loc[geoname_mismatch_idx]

# %% [markdown]
# #### Use split to get county and state

# %%
# Create DataFrame to split county and state
geo_name_df = bea_merge_df["GeoName_x"].str.rsplit(pat=", ", n= 1, expand=True)
geo_name_df[1] = geo_name_df[1].str.replace("*", "", regex=False)
geo_name_df[2] = bea_merge_df["GeoFips"]
geo_name_df
# Out:
#                0   1      2
# 0        Autauga  AL  01001
# 1        Baldwin  AL  01003
# 2        Barbour  AL  01005
# 3           Bibb  AL  01007
# 4         Blount  AL  01009
# ...          ...  ..    ...
# 3135  Sweetwater  WY  56037
# 3136       Teton  WY  56039
# 3137       Uinta  WY  56041
# 3138    Washakie  WY  56043
# 3139      Weston  WY  56045
#
# [3140 rows x 3 columns]

# %%
# geo_name_df[1].unique()
# len(geo_name_df[1].value_counts())
geo_name_df[1].count()
# Out:
# 3140

# %%
# Rename columnns
geo_name_df = geo_name_df.rename(columns={0: "county"})
geo_name_df = geo_name_df.rename(columns={1: "state"})
geo_name_df = geo_name_df.rename(columns={2: "GeoFips"})
geo_name_df
# Out:
#           county state GeoFips
# 0        Autauga    AL   01001
# 1        Baldwin    AL   01003
# 2        Barbour    AL   01005
# 3           Bibb    AL   01007
# 4         Blount    AL   01009
# ...          ...   ...     ...
# 3135  Sweetwater    WY   56037
# 3136       Teton    WY   56039
# 3137       Uinta    WY   56041
# 3138    Washakie    WY   56043
# 3139      Weston    WY   56045
#
# [3140 rows x 3 columns]

# %%
# Saving file as reference
geo_name_df.to_csv("Resources/geo_name_df.csv")

# %% [markdown]
# #### Merge county & state with income & population

# %%
# Merge county and zip code
bea_county_merge_df = bea_merge_df.merge(geo_name_df, left_on="GeoFips", right_on="GeoFips")
bea_county_merge_df
# Out:
#      GeoFips       GeoName_x per_capita_income       GeoName_y population  \
# 0      01001     Autauga, AL             46814     Autauga, AL      56145
# 1      01003     Baldwin, AL             50953     Baldwin, AL     229287
# 2      01005     Barbour, AL             37850     Barbour, AL      24589
# 3      01007        Bibb, AL             34300        Bibb, AL      22136
# 4      01009      Blount, AL             38808      Blount, AL      57879
# ...      ...             ...               ...             ...        ...
# 3135   56037  Sweetwater, WY             54000  Sweetwater, WY      42673
# 3136   56039       Teton, WY            220645       Teton, WY      23497
# 3137   56041       Uinta, WY             42854       Uinta, WY      20215
# 3138   56043    Washakie, WY             54361    Washakie, WY       7760
# 3139   56045      Weston, WY             47599      Weston, WY       6743
#
#           county state
# 0        Autauga    AL
# 1        Baldwin    AL
# 2        Barbour    AL
# 3           Bibb    AL
# 4         Blount    AL
# ...          ...   ...
# 3135  Sweetwater    WY
# 3136       Teton    WY
# 3137       Uinta    WY
# 3138    Washakie    WY
# 3139      Weston    WY
#
# [3140 rows x 7 columns]

# %%
# Drop redundant columns
bea_county_merge_df.drop(columns=["GeoName_x", "GeoName_y"], inplace=True)
bea_county_merge_df
# Out:
#      GeoFips per_capita_income population      county state
# 0      01001             46814      56145     Autauga    AL
# 1      01003             50953     229287     Baldwin    AL
# 2      01005             37850      24589     Barbour    AL
# 3      01007             34300      22136        Bibb    AL
# 4      01009             38808      57879      Blount    AL
# ...      ...               ...        ...         ...   ...
# 3135   56037             54000      42673  Sweetwater    WY
# 3136   56039            220645      23497       Teton    WY
# 3137   56041             42854      20215       Uinta    WY
# 3138   56043             54361       7760    Washakie    WY
# 3139   56045             47599       6743      Weston    WY
#
# [3140 rows x 5 columns]

# %%
# Move zip code column to 1st column (not index).  Move city and state immediately after.
bea_county_merge_df = bea_county_merge_df[["GeoFips", "county", "state", "population", "per_capita_income"]]
bea_county_merge_df
# Out:
#      GeoFips      county state population per_capita_income
# 0      01001     Autauga    AL      56145             46814
# 1      01003     Baldwin    AL     229287             50953
# 2      01005     Barbour    AL      24589             37850
# 3      01007        Bibb    AL      22136             34300
# 4      01009      Blount    AL      57879             38808
# ...      ...         ...   ...        ...               ...
# 3135   56037  Sweetwater    WY      42673             54000
# 3136   56039       Teton    WY      23497            220645
# 3137   56041       Uinta    WY      20215             42854
# 3138   56043    Washakie    WY       7760             54361
# 3139   56045      Weston    WY       6743             47599
#
# [3140 rows x 5 columns]

# %%
# Saving file as reference
bea_county_merge_df.to_csv("Resources/bea_county_merge_df.csv")

# %% [markdown]
# #### Create database for zip code / county

# %%
# Link as reference:
# https://www.unitedstateszipcodes.org/zip-code-database/

# %%
# Set dtypes prior to reading in csv file
zip_county_dtypes = {"zip": str}

# %%
# Create DataFrame
zip_county_df = pd.read_csv("Resources/zip_code_database.csv", dtype=zip_county_dtypes)
zip_county_df
# Out:
#          zip      type  decommissioned primary_city acceptable_cities  \
# 0      00501    UNIQUE               0   Holtsville               NaN
# 1      00544    UNIQUE               0   Holtsville               NaN
# 2      00601  STANDARD               0     Adjuntas               NaN
# 3      00602  STANDARD               0       Aguada               NaN
# 4      00603  STANDARD               0    Aguadilla             Ramey
# ...      ...       ...             ...          ...               ...
# 42719  99926    PO BOX               0   Metlakatla               NaN
# 42720  99927    PO BOX               0  Point Baker               NaN
# 42721  99928    PO BOX               0    Ward Cove               NaN
# 42722  99929    PO BOX               0     Wrangell               NaN
# 42723  99950    PO BOX               0    Ketchikan  Edna Bay, Kasaan
#
#                                      unacceptable_cities state  \
# 0                               Internal Revenue Service    NY
# 1                               Internal Revenue Service    NY
# 2      Colinas Del Gigante, Jard De Adjuntas, Urb San...    PR
# 3      Alts De Aguada, Bo Guaniquilla, Comunidad Las ...    PR
# 4      Bda Caban, Bda Esteves, Bo Borinquen, Bo Ceiba...    PR
# ...                                                  ...   ...
# 42719                                                NaN    AK
# 42720                                                NaN    AK
# 42721                                                NaN    AK
# 42722                                                NaN    AK
# 42723                                                NaN    AK
#
#                                         county             timezone  \
# 0                               Suffolk County     America/New_York
# 1                               Suffolk County     America/New_York
# 2                           Adjuntas Municipio  America/Puerto_Rico
# 3                             Aguada Municipio  America/Puerto_Rico
# 4                          Aguadilla Municipio  America/Puerto_Rico
# ...                                        ...                  ...
# 42719  Prince of Wales-Outer Ketchikan Borough   America/Metlakatla
# 42720        Prince of Wales-Hyder Census Area        America/Sitka
# 42721                Ketchikan Gateway Borough        America/Sitka
# 42722                Wrangell City and Borough        America/Sitka
# 42723  Prince of Wales-Outer Ketchikan Borough        America/Sitka
#
#       area_codes world_region country  latitude  longitude  \
# 0            631          NaN      US     40.81     -73.04
# 1            631          NaN      US     40.81     -73.04
# 2        787,939          NaN      US     18.16     -66.72
# 3        787,939          NaN      US     18.38     -67.18
# 4            787          NaN      US     18.43     -67.15
# ...          ...          ...     ...       ...        ...
# 42719        907          NaN      US     55.14    -131.49
# 42720        907          NaN      US     56.30    -133.57
# 42721        907          NaN      US     55.45    -131.79
# 42722        907          NaN      US     56.41    -131.61
# 42723        907          NaN      US     55.34    -131.64
#
#        irs_estimated_population
# 0                           562
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 42719                      1140
# 42720                        48
# 42721                      1530
# 42722                      2145
# 42723                       262
#
# [42724 rows x 15 columns]

# %%
# Check count
zip_county_df.count()
# Out:
# zip                         42724
# type                        42724
# decommissioned              42724
# primary_city                42724
# acceptable_cities            9287
# unacceptable_cities         11666
# state                       42724
# county                      41799
# timezone                    41926
# area_codes                  39698
# world_region                  333
# country                     42650
# latitude                    42724
# longitude                   42724
# irs_estimated_population    42724
# dtype: int64

# %%
# List columns
zip_county_df.columns.tolist()
# Out:
# ['zip',
#  'type',
#  'decommissioned',
#  'primary_city',
#  'acceptable_cities',
#  'unacceptable_cities',
#  'state',
#  'county',
#  'timezone',
#  'area_codes',
#  'world_region',
#  'country',
#  'latitude',
#  'longitude',
#  'irs_estimated_population']

# %%
# Columns to drop
zip_county_df.drop(columns=["type", "decommissioned", "primary_city", "acceptable_cities", "unacceptable_cities", 
                            "state", "timezone", "area_codes", "world_region", "country", "irs_estimated_population"]
                   , inplace=True)
zip_county_df
# Out:
#          zip                                   county  latitude  longitude
# 0      00501                           Suffolk County     40.81     -73.04
# 1      00544                           Suffolk County     40.81     -73.04
# 2      00601                       Adjuntas Municipio     18.16     -66.72
# 3      00602                         Aguada Municipio     18.38     -67.18
# 4      00603                      Aguadilla Municipio     18.43     -67.15
# ...      ...                                      ...       ...        ...
# 42719  99926  Prince of Wales-Outer Ketchikan Borough     55.14    -131.49
# 42720  99927        Prince of Wales-Hyder Census Area     56.30    -133.57
# 42721  99928                Ketchikan Gateway Borough     55.45    -131.79
# 42722  99929                Wrangell City and Borough     56.41    -131.61
# 42723  99950  Prince of Wales-Outer Ketchikan Borough     55.34    -131.64
#
# [42724 rows x 4 columns]

# %%
# Check count
zip_county_df.count()
# Out:
# zip          42724
# county       41799
# latitude     42724
# longitude    42724
# dtype: int64

# %%
# Check dtypes
zip_county_df.dtypes
# Out:
# zip           object
# county        object
# latitude     float64
# longitude    float64
# dtype: object

# %%
# Create series of "zip"
county_s = zip_county_df["zip"]
county_s
# Out:
# 0        00501
# 1        00544
# 2        00601
# 3        00602
# 4        00603
#          ...
# 42719    99926
# 42720    99927
# 42721    99928
# 42722    99929
# 42723    99950
# Name: zip, Length: 42724, dtype: object

# %%
# Check number of digits for each zip
county_s_len = county_s.map(len)
county_s_len
# Out:
# 0        5
# 1        5
# 2        5
# 3        5
# 4        5
#         ..
# 42719    5
# 42720    5
# 42721    5
# 42722    5
# 42723    5
# Name: zip, Length: 42724, dtype: int64

# %%
# Count of digit lengths
county_s_len.value_counts()
# Out:
# 5    42724
# Name: zip, dtype: int64

# %% [markdown]
# #### Merge county and zip code

# %%
# Check count before merge
bea_county_merge_df.count()
# Out:
# GeoFips              3140
# county               3140
# state                3140
# population           3140
# per_capita_income    3140
# dtype: int64

# %%
# Check count before merge
zip_county_df.count()
# Out:
# zip          42724
# county       41799
# latitude     42724
# longitude    42724
# dtype: int64

# %%
# Merge county and zip code
zip_county_merge_df = bea_county_merge_df.merge(zip_county_df, left_on="county", right_on="county")
zip_county_merge_df
# Out:
#     GeoFips                  county state population per_capita_income    zip  \
# 0     02013  Aleutians East Borough    AK       3401             59574  99553
# 1     02013  Aleutians East Borough    AK       3401             59574  99571
# 2     02013  Aleutians East Borough    AK       3401             59574  99583
# 3     02013  Aleutians East Borough    AK       3401             59574  99612
# 4     02013  Aleutians East Borough    AK       3401             59574  99661
# ..      ...                     ...   ...        ...               ...    ...
# 559   11001    District of Columbia    DC     712816             86567  56945
# 560   11001    District of Columbia    DC     712816             86567  56950
# 561   11001    District of Columbia    DC     712816             86567  56965
# 562   11001    District of Columbia    DC     712816             86567  56972
# 563   51036            Charles City    VA       6821             51498  23147
#
#      latitude  longitude
# 0       54.12    -165.83
# 1       55.22    -162.78
# 2       54.89    -163.41
# 3       55.08    -162.32
# 4       55.26    -160.66
# ..        ...        ...
# 559     38.89     -77.03
# 560     38.89     -77.03
# 561     38.89     -77.03
# 562     38.86     -76.99
# 563     37.36     -77.04
#
# [564 rows x 8 columns]

# %%
# DEBUG - WHY IS NUMBER OF ROWS SO SMALL?

# %%
# Saving file as reference
zip_county_merge_df.to_csv("Resources/zip_county_merge_df.csv")

# %% [markdown]
# ### Create DataFrame for Physicians
# #### Original version (source: cms.gov, updated Jan 2022)

# %%
# Link as reference:
# https://data.cms.gov/provider-data/dataset/mj5m-pzi6

# %%
# with open("Resources/physician_data.csv", "rb") as csv_file:
#     rawdata = csv_file.read()
#     chardet.detect(rawdata)

# %%
# import chardet
# rawdata = open("Resources/physician_data.csv", 'rb').read()
# result = chardet.detect(rawdata)
# charenc = result['encoding']

# %%
# print(result)

# %% [markdown]
# ### Use original dataframe or Michigan only?

# %%
# Set dtypes prior to reading in csv file
physicians_dtypes = {"zip": str, "grd_yr": str}

# %%
# Original DataFrame: all states
# physicians_original_df = pd.read_csv("Resources/physician_data.csv", encoding="ISO-8859-1", dtype=physicians_dtypes)
# physicians_original_df

# %%
# Michigan DataFrame: Michigan only
physicians_original_df = pd.read_csv("Resources/michigan_physician_data.csv", encoding="ISO-8859-1", dtype=physicians_dtypes)
physicians_original_df
# Out:
#                npi grd_yr                pri_spec              cty  st  \
# 0       1215376108   2013      ALLERGY/IMMUNOLOGY           LAPEER  MI
# 1       1215234745   2007           OPHTHALMOLOGY          PORTAGE  MI
# 2       1215167812   1998         FAMILY MEDICINE          DETROIT  MI
# 3       1215178306   2001  CLINICAL SOCIAL WORKER          JACKSON  MI
# 4       1215172580   1977  PSYCHOLOGIST, CLINICAL  WEST BLOOMFIELD  MI
# ...            ...    ...                     ...              ...  ..
# 104570  1306272042   2011  PSYCHOLOGIST, CLINICAL        ANN ARBOR  MI
# 104571  1487107249   2015                PODIATRY             ALMA  MI
# 104572  1679837504   2012                PODIATRY             ALMA  MI
# 104573  1033648944   2015            CHIROPRACTIC         BAY CITY  MI
# 104574  1407245814   2014            CHIROPRACTIC         BAY CITY  MI
#
#               zip ind_assgn grp_assgn
# 0       484464421         Y         M
# 1       490241232         Y         M
# 2       482271749         Y         M
# 3       492033652         Y         M
# 4       483223784         Y         M
# ...           ...       ...       ...
# 104570  481058800         Y         Y
# 104571  488011026         Y         Y
# 104572  488011026         Y         Y
# 104573  487063318         Y         Y
# 104574  487063318         Y         Y
#
# [104575 rows x 8 columns]

# %%
# NOTE: NEED TO CHANGE TYPE FOR NPI?

physicians_original_df.dtypes
# Out:
# npi           int64
# grd_yr       object
# pri_spec     object
# cty          object
# st           object
# zip          object
# ind_assgn    object
# grp_assgn    object
# dtype: object

# %%
# Create series of "zip"
physicians_zip_s = physicians_original_df["zip"]
physicians_zip_s
# Out:
# 0         484464421
# 1         490241232
# 2         482271749
# 3         492033652
# 4         483223784
#             ...
# 104570    481058800
# 104571    488011026
# 104572    488011026
# 104573    487063318
# 104574    487063318
# Name: zip, Length: 104575, dtype: object

# %%
# Check number of digits for each zip
physicians_zip_len = physicians_zip_s.map(len)
physicians_zip_len
# Out:
# 0         9
# 1         9
# 2         9
# 3         9
# 4         9
#          ..
# 104570    9
# 104571    9
# 104572    9
# 104573    9
# 104574    9
# Name: zip, Length: 104575, dtype: int64

# %%
# Count of digit lengths
physicians_zip_len.value_counts()
# Out:
# 9    104450
# 5       125
# Name: zip, dtype: int64

# %%
# Apply function to standardize number of zip digits
physicians_zip_five_s = physicians_zip_s.map(first_five)
physicians_zip_five_s
# Out:
# 0         48446
# 1         49024
# 2         48227
# 3         49203
# 4         48322
#           ...
# 104570    48105
# 104571    48801
# 104572    48801
# 104573    48706
# 104574    48706
# Name: zip, Length: 104575, dtype: object

# %%
# Apply function to standardize number of zip digits
physicians_original_df["zip"] = physicians_zip_five_s
physicians_original_df
# Out:
#                npi grd_yr                pri_spec              cty  st    zip  \
# 0       1215376108   2013      ALLERGY/IMMUNOLOGY           LAPEER  MI  48446
# 1       1215234745   2007           OPHTHALMOLOGY          PORTAGE  MI  49024
# 2       1215167812   1998         FAMILY MEDICINE          DETROIT  MI  48227
# 3       1215178306   2001  CLINICAL SOCIAL WORKER          JACKSON  MI  49203
# 4       1215172580   1977  PSYCHOLOGIST, CLINICAL  WEST BLOOMFIELD  MI  48322
# ...            ...    ...                     ...              ...  ..    ...
# 104570  1306272042   2011  PSYCHOLOGIST, CLINICAL        ANN ARBOR  MI  48105
# 104571  1487107249   2015                PODIATRY             ALMA  MI  48801
# 104572  1679837504   2012                PODIATRY             ALMA  MI  48801
# 104573  1033648944   2015            CHIROPRACTIC         BAY CITY  MI  48706
# 104574  1407245814   2014            CHIROPRACTIC         BAY CITY  MI  48706
#
#        ind_assgn grp_assgn
# 0              Y         M
# 1              Y         M
# 2              Y         M
# 3              Y         M
# 4              Y         M
# ...          ...       ...
# 104570         Y         Y
# 104571         Y         Y
# 104572         Y         Y
# 104573         Y         Y
# 104574         Y         Y
#
# [104575 rows x 8 columns]

# %%
# Check number of digits for each zip
physicians_zip_len = physicians_zip_s.map(len)
physicians_zip_len
# Out:
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
#          ..
# 104570    5
# 104571    5
# 104572    5
# 104573    5
# 104574    5
# Name: zip, Length: 104575, dtype: int64

# %%
# Count of digit lengths
physicians_zip_len.value_counts()
# Out:
# 5    104575
# Name: zip, dtype: int64

# %%
# Find null values
for column in physicians_original_df.columns:
    print(f"Column {column} has {physicians_original_df[column].isnull().sum()} null values")
# Out:
# Column npi has 0 null values
# Column grd_yr has 63 null values
# Column pri_spec has 0 null values
# Column cty has 0 null values
# Column st has 0 null values
# Column zip has 0 null values
# Column ind_assgn has 0 null values
# Column grp_assgn has 0 null values

# %% [markdown]
# ### Additional steps for Rev 04 to filter by Michigan and only primary care physicians

# %%
# Filter by state of Michigan only
# NOT NEEDED IF WE START WITH MICHIGAN ONLY DATA

# physicians_original_df = physicians_original_df.loc[physicians_original_df["st"] == "MI"]
# physicians_original_df

# %%
# Find all unique names for Primary Specialty
physicians_original_df.pri_spec.unique()
# Out:
# array(['ALLERGY/IMMUNOLOGY', 'OPHTHALMOLOGY', 'FAMILY MEDICINE',
#        'CLINICAL SOCIAL WORKER', 'PSYCHOLOGIST, CLINICAL', 'CHIROPRACTIC',
#        'PHYSICAL THERAPY', 'NURSE PRACTITIONER', 'PODIATRY', 'OPTOMETRY',
#        'INTERNAL MEDICINE', 'PSYCHIATRY', 'GENERAL PRACTICE', 'NEUROLOGY',
#        'PHYSICAL MEDICINE AND REHABILITATION', 'DERMATOLOGY',
#        'GENERAL SURGERY', 'OBSTETRICS/GYNECOLOGY',
#        'PREVENTATIVE MEDICINE', 'ORTHOPEDIC SURGERY', 'RHEUMATOLOGY',
#        'PULMONARY DISEASE', 'UNDERSEA AND HYPERBARIC MEDICINE',
#        'PAIN MANAGEMENT', 'OTOLARYNGOLOGY',
#        'QUALIFIED SPEECH LANGUAGE PATHOLOGIST', 'GASTROENTEROLOGY',
#        'PEDIATRIC MEDICINE', 'CRITICAL CARE (INTENSIVISTS)',
#        'EMERGENCY MEDICINE', 'QUALIFIED AUDIOLOGIST', 'ORAL SURGERY',
#        'CARDIOVASCULAR DISEASE (CARDIOLOGY)', 'UROLOGY', 'SLEEP MEDICINE',
#        'REGISTERED DIETITIAN OR NUTRITION PROFESSIONAL',
#        'DIAGNOSTIC RADIOLOGY', 'NEUROSURGERY', 'GERIATRIC MEDICINE',
#        'INTERVENTIONAL RADIOLOGY', 'INTERVENTIONAL PAIN MANAGEMENT',
#        'COLORECTAL SURGERY (PROCTOLOGY)', 'NEPHROLOGY',
#        'VASCULAR SURGERY', 'PHYSICIAN ASSISTANT',
#        'PLASTIC AND RECONSTRUCTIVE SURGERY', 'ENDOCRINOLOGY',
#        'INFECTIOUS DISEASE', 'ANESTHESIOLOGY', 'SPORTS MEDICINE',
#        'HEMATOLOGY/ONCOLOGY', 'OCCUPATIONAL THERAPY',
#        'MAXILLOFACIAL SURGERY', 'THORACIC SURGERY',
#        'CERTIFIED REGISTERED NURSE ANESTHETIST (CRNA)',
#        'OSTEOPATHIC MANIPULATIVE MEDICINE', 'DENTIST', 'CARDIAC SURGERY',
#        'CERTIFIED NURSE MIDWIFE (CNM)', 'HOSPITALIST',
#        'CARDIAC ELECTROPHYSIOLOGY', 'PATHOLOGY',
#        'INTERVENTIONAL CARDIOLOGY', 'MEDICAL ONCOLOGY', 'HAND SURGERY',
#        'ADVANCED HEART FAILURE AND TRANSPLANT CARDIOLOGY',
#        'RADIATION ONCOLOGY', 'MICROGRAPHIC DERMATOLOGIC SURGERY (MDS)',
#        'GYNECOLOGICAL ONCOLOGY', 'HEMATOLOGY', 'HOSPICE/PALLIATIVE CARE',
#        'ADULT CONGENITAL HEART DISEASE (ACHD)', 'ADDICTION MEDICINE',
#        'CERTIFIED CLINICAL NURSE SPECIALIST (CNS)', 'NEUROPSYCHIATRY',
#        'HEMATOPOIETIC CELL TRANSPLANTATION AND CELLULAR THERAPY',
#        'SURGICAL ONCOLOGY', 'ANESTHESIOLOGY ASSISTANT',
#        'NUCLEAR MEDICINE', 'GERIATRIC PSYCHIATRY',
#        'MEDICAL GENETICS AND GENOMICS'], dtype=object)

# %%
# Filter by general practice / primary care
# NOTE: DISCUSS WITH TEAM IF WE WANT TO MODIFY SELECTION

# 'FAMILY MEDICINE'
# 'NURSE PRACTITIONER'
# 'GENERAL PRACTICE'
# 'PREVENTATIVE MEDICINE'
# 'EMERGENCY MEDICINE'
# 'PHYSICIAN ASSISTANT'
# 'INTERNAL MEDICINE'
# 'PEDIATRIC MEDICINE'
# 'OBSTETRICS/GYNECOLOGY'

# df.loc[(df['column_name'] >= A) & (df['column_name'] <= B)]

physicians_original_df = physicians_original_df.loc[
    (physicians_original_df["pri_spec"] == 'FAMILY MEDICINE') |
    (physicians_original_df["pri_spec"] == 'NURSE PRACTITIONER') |
    (physicians_original_df["pri_spec"] == 'GENERAL PRACTICE') |
    (physicians_original_df["pri_spec"] == 'PREVENTATIVE MEDICINE') |
    (physicians_original_df["pri_spec"] == 'EMERGENCY MEDICINE') |
    (physicians_original_df["pri_spec"] == 'PHYSICIAN ASSISTANT') |
    (physicians_original_df["pri_spec"] == 'INTERNAL MEDICINE') |
    (physicians_original_df["pri_spec"] == 'PEDIATRIC MEDICINE') |
    (physicians_original_df["pri_spec"] == 'OBSTETRICS/GYNECOLOGY'
)]
physicians_original_df
# Out:
#                npi grd_yr            pri_spec         cty  st    zip  \
# 2       1215167812   1998     FAMILY MEDICINE     DETROIT  MI  48227
# 9       1215385851   2015  NURSE PRACTITIONER  SOUTHFIELD  MI  48076
# 18      1215021472   1991   INTERNAL MEDICINE       FLINT  MI  48532
# 21      1215059241   1977    GENERAL PRACTICE     JENISON  MI  49428
# 22      1215038906   1976   INTERNAL MEDICINE    ST JOHNS  MI  48879
# ...            ...    ...                 ...         ...  ..    ...
# 104558  1902288947   2015  EMERGENCY MEDICINE      OWOSSO  MI  48867
# 104560  1043621451   2014   INTERNAL MEDICINE      WARREN  MI  48088
# 104561  1366418667   1975   INTERNAL MEDICINE      WARREN  MI  48088
# 104565  1720035991   1978   INTERNAL MEDICINE      WARREN  MI  48088
# 104567  1831324565   2009     FAMILY MEDICINE      WARREN  MI  48088
#
#        ind_assgn grp_assgn
# 2              Y         M
# 9              Y         M
# 18             Y         M
# 21             Y         M
# 22             Y         M
# ...          ...       ...
# 104558         Y         Y
# 104560         Y         Y
# 104561         Y         Y
# 104565         Y         Y
# 104567         Y         Y
#
# [40280 rows x 8 columns]

# %%
# Check unique names for Primary Specialty after filtering
physicians_original_df.pri_spec.unique()
# Out:
# array(['FAMILY MEDICINE', 'NURSE PRACTITIONER', 'INTERNAL MEDICINE',
#        'GENERAL PRACTICE', 'OBSTETRICS/GYNECOLOGY',
#        'PREVENTATIVE MEDICINE', 'PEDIATRIC MEDICINE',
#        'EMERGENCY MEDICINE', 'PHYSICIAN ASSISTANT'], dtype=object)

# %% [markdown]
# ### Create DataFrame for Income versus Zip Code
# #### Original version (source: kaggle, 2018)

# %%
# Link for reference:
# https://www.kaggle.com/hamishgunasekara/average-income-per-zip-code-usa-2018

# %%
# Set dtypes prior to reading in csv file
income_dtypes = {"zipcode": str}

# %%
# Read in csv and create DataFrame
income_original_df = pd.read_csv("Resources/postcode_level_averages.csv", dtype=income_dtypes)
income_original_df
# Out:
#       state zipcode  total_pop  total_income country     avg_income
# 0        AK       0     345220      25354974     USA   73445.843230
# 1        AK   99501       7690        612242     USA   79615.344603
# 2        AK   99502      11860       1000685     USA   84374.789207
# 3        AK   99503       7510        462394     USA   61570.439414
# 4        AK   99504      19440       1176109     USA   60499.434156
# ...     ...     ...        ...           ...     ...            ...
# 27653    WY   83126        200         17041     USA   85205.000000
# 27654    WY   83127       1620        135778     USA   83813.580247
# 27655    WY   83128        950        119435     USA  125721.052632
# 27656    WY   83414        230         60700     USA  263913.043478
# 27657    WY   99999      15820       1376755     USA   87026.232617
#
# [27658 rows x 6 columns]

# %%
# Check dtypes
income_original_df.dtypes
# Out:
# state            object
# zipcode          object
# total_pop         int64
# total_income      int64
# country          object
# avg_income      float64
# dtype: object

# %%
# Create series of "zip"
income_zip_s = income_original_df["zipcode"]
income_zip_s
# Out:
# 0            0
# 1        99501
# 2        99502
# 3        99503
# 4        99504
#          ...
# 27653    83126
# 27654    83127
# 27655    83128
# 27656    83414
# 27657    99999
# Name: zipcode, Length: 27658, dtype: object

# %%
# Check number of digits for each zip
income_zip_len = income_zip_s.map(len)
income_zip_len
# Out:
# 0        1
# 1        5
# 2        5
# 3        5
# 4        5
#         ..
# 27653    5
# 27654    5
# 27655    5
# 27656    5
# 27657    5
# Name: zipcode, Length: 27658, dtype: int64

# %%
# Count of digit lengths
income_zip_len.value_counts()
# Out:
# 5    25420
# 4     2187
# 1       51
# Name: zipcode, dtype: int64

# %%
# Apply function to standardize number of zip digits
income_zip_five_s = income_zip_s.map(normalize_zip)
income_zip_five_s
# Out:
# 0        00000
# 1        99501
# 2        99502
# 3        99503
# 4        99504
#          ...
# 27653    83126
# 27654    83127
# 27655    83128
# 27656    83414
# 27657    99999
# Name: zipcode, Length: 27658, dtype: object

# %%
# Apply function to standardize number of zip digits
income_original_df["zipcode"] = income_zip_five_s
income_original_df
# Out:
#       state zipcode  total_pop  total_income country     avg_income
# 0        AK   00000     345220      25354974     USA   73445.843230
# 1        AK   99501       7690        612242     USA   79615.344603
# 2        AK   99502      11860       1000685     USA   84374.789207
# 3        AK   99503       7510        462394     USA   61570.439414
# 4        AK   99504      19440       1176109     USA   60499.434156
# ...     ...     ...        ...           ...     ...            ...
# 27653    WY   83126        200         17041     USA   85205.000000
# 27654    WY   83127       1620        135778     USA   83813.580247
# 27655    WY   83128        950        119435     USA  125721.052632
# 27656    WY   83414        230         60700     USA  263913.043478
# 27657    WY   99999      15820       1376755     USA   87026.232617
#
# [27658 rows x 6 columns]

# %%
# Check number of digits for each zip
income_zip_len = income_zip_s.map(len)
income_zip_len
# Out:
# 0        5
# 1        5
# 2        5
# 3        5
# 4        5
#         ..
# 27653    5
# 27654    5
# 27655    5
# 27656    5
# 27657    5
# Name: zipcode, Length: 27658, dtype: int64

# %%
# Count of digit lengths
income_zip_len.value_counts()
# Out:
# 5    27658
# Name: zipcode, dtype: int64

# %%
# Remove irrelevant "country" column
income_original_df.drop(columns="country", inplace=True)
income_original_df
# Out:
#       state zipcode  total_pop  total_income     avg_income
# 0        AK   00000     345220      25354974   73445.843230
# 1        AK   99501       7690        612242   79615.344603
# 2        AK   99502      11860       1000685   84374.789207
# 3        AK   99503       7510        462394   61570.439414
# 4        AK   99504      19440       1176109   60499.434156
# ...     ...     ...        ...           ...            ...
# 27653    WY   83126        200         17041   85205.000000
# 27654    WY   83127       1620        135778   83813.580247
# 27655    WY   83128        950        119435  125721.052632
# 27656    WY   83414        230         60700  263913.043478
# 27657    WY   99999      15820       1376755   87026.232617
#
# [27658 rows x 5 columns]

# %%
# Find null values
for column in income_original_df.columns:
    print(f"Column {column} has {income_original_df[column].isnull().sum()} null values")
# Out:
# Column state has 0 null values
# Column zipcode has 0 null values
# Column total_pop has 0 null values
# Column total_income has 0 null values
# Column avg_income has 0 null values

# %%
# Saving file as reference
income_original_df.to_csv("Resources/income_original_df.csv")

# %% [markdown]
# ### Additional steps for Rev 04 to filter by Michigan

# %%
# Filter by state of Michigan only
income_original_df = income_original_df.loc[income_original_df["state"] == "MI"]
income_original_df
# Out:
#       state zipcode  total_pop  total_income     avg_income
# 11153    MI   00000    4729780     320740706   67813.028513
# 11154    MI   48001       6270        385108   61420.733652
# 11155    MI   48002       1520        102460   67407.894737
# 11156    MI   48003       3220        210579   65397.204969
# 11157    MI   48005       2700        210225   77861.111111
# ...     ...     ...        ...           ...            ...
# 12040    MI   49967        210          9768   46514.285714
# 12041    MI   49968        930         39279   42235.483871
# 12042    MI   49969        590        132776  225044.067797
# 12043    MI   49970        110          4691   42645.454545
# 12044    MI   99999      43590       2986134   68505.024088
#
# [892 rows x 5 columns]

# %% [markdown]
# ### Create Dataframe for ZCTA info
# #### Original version
# #### https://simplemaps.com/data/us-zips
# #### * Note: All code in this section is identical to Jenny's ZCTAMI.ipynb file unless noted in comments

# %%
# NOTE: MODIFIED FROM JENNY'S FILE.  ZIPCODE CHANGED TO A STRING.

zipcode_dtypes = {"zip": str}

# %%
# NOTE: MODIFIED FROM JENNY'S FILE.  ZIPCODE CHANGED TO A STRING.

zip_data_df = pd.read_csv("Resources/uszips.csv", dtype=zipcode_dtypes)
zip_data_df
# Out:
#          zip       lat        lng         city state_id   state_name  zcta  \
# 0      00601  18.18005  -66.75218     Adjuntas       PR  Puerto Rico  True
# 1      00602  18.36074  -67.17519       Aguada       PR  Puerto Rico  True
# 2      00603  18.45440  -67.12201    Aguadilla       PR  Puerto Rico  True
# 3      00606  18.16721  -66.93828      Maricao       PR  Puerto Rico  True
# 4      00610  18.29032  -67.12244       Anasco       PR  Puerto Rico  True
# ...      ...       ...        ...          ...      ...          ...   ...
# 33115  99923  55.97796 -130.03671        Hyder       AK       Alaska  True
# 33116  99925  55.55796 -132.97482      Klawock       AK       Alaska  True
# 33117  99926  55.12617 -131.48928   Metlakatla       AK       Alaska  True
# 33118  99927  56.25100 -133.37572  Point Baker       AK       Alaska  True
# 33119  99929  56.36950 -131.93648     Wrangell       AK       Alaska  True
#
#        parent_zcta  population  density  county_fips            county_name  \
# 0              NaN     17113.0    102.7        72001               Adjuntas
# 1              NaN     37751.0    476.0        72003                 Aguada
# 2              NaN     47081.0    574.9        72005              Aguadilla
# 3              NaN      6392.0     58.3        72093                Maricao
# 4              NaN     26686.0    286.9        72011                 Añasco
# ...            ...         ...      ...          ...                    ...
# 33115          NaN        14.0      0.3         2198  Prince of Wales-Hyder
# 33116          NaN       908.0      6.3         2198  Prince of Wales-Hyder
# 33117          NaN      1654.0      4.8         2198  Prince of Wales-Hyder
# 33118          NaN         0.0      0.0         2198  Prince of Wales-Hyder
# 33119          NaN      2502.0      0.4         2275               Wrangell
#
#                                           county_weights  \
# 0                    {"72001": "99.43", "72141": "0.57"}
# 1                                       {"72003": "100"}
# 2                                       {"72005": "100"}
# 3      {"72093": "94.88", "72153": "3.78", "72121": "...
# 4                    {"72011": "99.45", "72003": "0.55"}
# ...                                                  ...
# 33115                                   {"02198": "100"}
# 33116                                   {"02198": "100"}
# 33117                                   {"02198": "100"}
# 33118                                   {"02198": "100"}
# 33119                                   {"02275": "100"}
#
#                   county_names_all    county_fips_all  imprecise  military  \
# 0                  Adjuntas|Utuado        72001|72141      False     False
# 1                           Aguada              72003      False     False
# 2                        Aguadilla              72005      False     False
# 3      Maricao|Yauco|Sabana Grande  72093|72153|72121      False     False
# 4                    Añasco|Aguada        72011|72003      False     False
# ...                            ...                ...        ...       ...
# 33115        Prince of Wales-Hyder              02198      False     False
# 33116        Prince of Wales-Hyder              02198      False     False
# 33117        Prince of Wales-Hyder              02198      False     False
# 33118        Prince of Wales-Hyder              02198      False     False
# 33119                     Wrangell              02275      False     False
#
#                   timezone
# 0      America/Puerto_Rico
# 1      America/Puerto_Rico
# 2      America/Puerto_Rico
# 3      America/Puerto_Rico
# 4      America/Puerto_Rico
# ...                    ...
# 33115        America/Sitka
# 33116        America/Sitka
# 33117   America/Metlakatla
# 33118        America/Sitka
# 33119        America/Sitka
#
# [33120 rows x 18 columns]

# %%
# Column types
zip_data_df.dtypes
# Out:
# zip                  object
# lat                 float64
# lng                 float64
# city                 object
# state_id             object
# state_name           object
# zcta                   bool
# parent_zcta         float64
# population          float64
# density             float64
# county_fips           int64
# county_name          object
# county_weights       object
# county_names_all     object
# county_fips_all      object
# imprecise              bool
# military               bool
# timezone             object
# dtype: object

# %%
# Row count
zip_data_df.count()
# Out:
# zip                 33120
# lat                 33120
# lng                 33120
# city                33120
# state_id            33120
# state_name          33120
# zcta                33120
# parent_zcta             0
# population          33096
# density             33096
# county_fips         33120
# county_name         33120
# county_weights      33120
# county_names_all    33120
# county_fips_all     33120
# imprecise           33120
# military            33120
# timezone            33120
# dtype: int64

# %%
# Drop duplicates
zip_data_df.drop_duplicates()
# Out:
#          zip       lat        lng         city state_id   state_name  zcta  \
# 0      00601  18.18005  -66.75218     Adjuntas       PR  Puerto Rico  True
# 1      00602  18.36074  -67.17519       Aguada       PR  Puerto Rico  True
# 2      00603  18.45440  -67.12201    Aguadilla       PR  Puerto Rico  True
# 3      00606  18.16721  -66.93828      Maricao       PR  Puerto Rico  True
# 4      00610  18.29032  -67.12244       Anasco       PR  Puerto Rico  True
# ...      ...       ...        ...          ...      ...          ...   ...
# 33115  99923  55.97796 -130.03671        Hyder       AK       Alaska  True
# 33116  99925  55.55796 -132.97482      Klawock       AK       Alaska  True
# 33117  99926  55.12617 -131.48928   Metlakatla       AK       Alaska  True
# 33118  99927  56.25100 -133.37572  Point Baker       AK       Alaska  True
# 33119  99929  56.36950 -131.93648     Wrangell       AK       Alaska  True
#
#        parent_zcta  population  density  county_fips            county_name  \
# 0              NaN     17113.0    102.7        72001               Adjuntas
# 1              NaN     37751.0    476.0        72003                 Aguada
# 2              NaN     47081.0    574.9        72005              Aguadilla
# 3              NaN      6392.0     58.3        72093                Maricao
# 4              NaN     26686.0    286.9        72011                 Añasco
# ...            ...         ...      ...          ...                    ...
# 33115          NaN        14.0      0.3         2198  Prince of Wales-Hyder
# 33116          NaN       908.0      6.3         2198  Prince of Wales-Hyder
# 33117          NaN      1654.0      4.8         2198  Prince of Wales-Hyder
# 33118          NaN         0.0      0.0         2198  Prince of Wales-Hyder
# 33119          NaN      2502.0      0.4         2275               Wrangell
#
#                                           county_weights  \
# 0                    {"72001": "99.43", "72141": "0.57"}
# 1                                       {"72003": "100"}
# 2                                       {"72005": "100"}
# 3      {"72093": "94.88", "72153": "3.78", "72121": "...
# 4                    {"72011": "99.45", "72003": "0.55"}
# ...                                                  ...
# 33115                                   {"02198": "100"}
# 33116                                   {"02198": "100"}
# 33117                                   {"02198": "100"}
# 33118                                   {"02198": "100"}
# 33119                                   {"02275": "100"}
#
#                   county_names_all    county_fips_all  imprecise  military  \
# 0                  Adjuntas|Utuado        72001|72141      False     False
# 1                           Aguada              72003      False     False
# 2                        Aguadilla              72005      False     False
# 3      Maricao|Yauco|Sabana Grande  72093|72153|72121      False     False
# 4                    Añasco|Aguada        72011|72003      False     False
# ...                            ...                ...        ...       ...
# 33115        Prince of Wales-Hyder              02198      False     False
# 33116        Prince of Wales-Hyder              02198      False     False
# 33117        Prince of Wales-Hyder              02198      False     False
# 33118        Prince of Wales-Hyder              02198      False     False
# 33119                     Wrangell              02275      False     False
#
#                   timezone
# 0      America/Puerto_Rico
# 1      America/Puerto_Rico
# 2      America/Puerto_Rico
# 3      America/Puerto_Rico
# 4      America/Puerto_Rico
# ...                    ...
# 33115        America/Sitka
# 33116        America/Sitka
# 33117   America/Metlakatla
# 33118        America/Sitka
# 33119        America/Sitka
#
# [33120 rows x 18 columns]

# %%
# Check for populations with 0
zip_data_df.sort_values(["population"], ascending=True)
# Out:
#          zip       lat        lng          city state_id  \
# 15892  48233  42.32370  -83.06166       Detroit       MI
# 2629   10173  40.75413  -73.97936      New York       NY
# 19235  56658  48.09036  -93.82919        Margie       MN
# 14420  44652  40.90044  -81.32618  Middlebranch       OH
# 2628   10172  40.75527  -73.97431      New York       NY
# ...      ...       ...        ...           ...      ...
# 31864  96929  13.56510  144.87620          Yigo       GU
# 31865  96932  13.47524  144.74216       Hagatna       GU
# 31866  96950  15.18887  145.75356        Saipan       MP
# 31867  96951  14.15733  145.21450          Rota       MP
# 31868  96952  15.01312  145.63149        Tinian       MP
#
#                      state_name  zcta  parent_zcta  population  density  \
# 15892                  Michigan  True          NaN         0.0      0.0
# 2629                   New York  True          NaN         0.0      0.0
# 19235                 Minnesota  True          NaN         0.0      0.0
# 14420                      Ohio  True          NaN         0.0      0.0
# 2628                   New York  True          NaN         0.0      0.0
# ...                         ...   ...          ...         ...      ...
# 31864                      Guam  True          NaN         NaN      NaN
# 31865                      Guam  True          NaN         NaN      NaN
# 31866  Northern Mariana Islands  True          NaN         NaN      NaN
# 31867  Northern Mariana Islands  True          NaN         NaN      NaN
# 31868  Northern Mariana Islands  True          NaN         NaN      NaN
#
#        county_fips  county_name    county_weights county_names_all  \
# 15892        26163        Wayne    {"26163": "0"}            Wayne
# 2629         36061     New York  {"36061": "100"}         New York
# 19235        27071  Koochiching  {"27071": "100"}      Koochiching
# 14420        39151        Stark  {"39151": "100"}            Stark
# 2628         36061     New York    {"36061": "0"}         New York
# ...            ...          ...               ...              ...
# 31864        66010         Guam    {"66010": 100}             Guam
# 31865        66010         Guam    {"66010": 100}             Guam
# 31866        69110       Saipan    {"69110": 100}           Saipan
# 31867        69100         Rota    {"69100": 100}             Rota
# 31868        69120       Tinian    {"69120": 100}           Tinian
#
#       county_fips_all  imprecise  military          timezone
# 15892           26163      False     False   America/Detroit
# 2629            36061      False     False  America/New_York
# 19235           27071      False     False   America/Chicago
# 14420           39151      False     False  America/New_York
# 2628            36061      False     False  America/New_York
# ...               ...        ...       ...               ...
# 31864           66010      False     False      Pacific/Guam
# 31865           66010      False     False      Pacific/Guam
# 31866           69110      False     False    Pacific/Saipan
# 31867           69100      False     False    Pacific/Saipan
# 31868           69120      False     False    Pacific/Saipan
#
# [33120 rows x 18 columns]

# %%
# Drop population values equal to zero 
zip_data_df.drop(zip_data_df.index[zip_data_df['population'] == 0], inplace = True)
zip_data_df
# Out:
#          zip       lat        lng        city state_id   state_name  zcta  \
# 0      00601  18.18005  -66.75218    Adjuntas       PR  Puerto Rico  True
# 1      00602  18.36074  -67.17519      Aguada       PR  Puerto Rico  True
# 2      00603  18.45440  -67.12201   Aguadilla       PR  Puerto Rico  True
# 3      00606  18.16721  -66.93828     Maricao       PR  Puerto Rico  True
# 4      00610  18.29032  -67.12244      Anasco       PR  Puerto Rico  True
# ...      ...       ...        ...         ...      ...          ...   ...
# 33114  99922  55.30211 -133.03248    Hydaburg       AK       Alaska  True
# 33115  99923  55.97796 -130.03671       Hyder       AK       Alaska  True
# 33116  99925  55.55796 -132.97482     Klawock       AK       Alaska  True
# 33117  99926  55.12617 -131.48928  Metlakatla       AK       Alaska  True
# 33119  99929  56.36950 -131.93648    Wrangell       AK       Alaska  True
#
#        parent_zcta  population  density  county_fips            county_name  \
# 0              NaN     17113.0    102.7        72001               Adjuntas
# 1              NaN     37751.0    476.0        72003                 Aguada
# 2              NaN     47081.0    574.9        72005              Aguadilla
# 3              NaN      6392.0     58.3        72093                Maricao
# 4              NaN     26686.0    286.9        72011                 Añasco
# ...            ...         ...      ...          ...                    ...
# 33114          NaN       342.0      1.1         2198  Prince of Wales-Hyder
# 33115          NaN        14.0      0.3         2198  Prince of Wales-Hyder
# 33116          NaN       908.0      6.3         2198  Prince of Wales-Hyder
# 33117          NaN      1654.0      4.8         2198  Prince of Wales-Hyder
# 33119          NaN      2502.0      0.4         2275               Wrangell
#
#                                           county_weights  \
# 0                    {"72001": "99.43", "72141": "0.57"}
# 1                                       {"72003": "100"}
# 2                                       {"72005": "100"}
# 3      {"72093": "94.88", "72153": "3.78", "72121": "...
# 4                    {"72011": "99.45", "72003": "0.55"}
# ...                                                  ...
# 33114                                   {"02198": "100"}
# 33115                                   {"02198": "100"}
# 33116                                   {"02198": "100"}
# 33117                                   {"02198": "100"}
# 33119                                   {"02275": "100"}
#
#                   county_names_all    county_fips_all  imprecise  military  \
# 0                  Adjuntas|Utuado        72001|72141      False     False
# 1                           Aguada              72003      False     False
# 2                        Aguadilla              72005      False     False
# 3      Maricao|Yauco|Sabana Grande  72093|72153|72121      False     False
# 4                    Añasco|Aguada        72011|72003      False     False
# ...                            ...                ...        ...       ...
# 33114        Prince of Wales-Hyder              02198      False     False
# 33115        Prince of Wales-Hyder              02198      False     False
# 33116        Prince of Wales-Hyder              02198      False     False
# 33117        Prince of Wales-Hyder              02198      False     False
# 33119                     Wrangell              02275      False     False
#
#                   timezone
# 0      America/Puerto_Rico
# 1      America/Puerto_Rico
# 2      America/Puerto_Rico
# 3      America/Puerto_Rico
# 4      America/Puerto_Rico
# ...                    ...
# 33114        America/Sitka
# 33115        America/Sitka
# 33116        America/Sitka
# 33117   America/Metlakatla
# 33119        America/Sitka
#
# [32782 rows x 18 columns]

# %%
# Drop population if null (most are duplicates)
zip_data_df.drop(zip_data_df.index[zip_data_df['population'] == "NaN"], inplace = True)
zip_data_df
# Out:
#          zip       lat        lng        city state_id   state_name  zcta  \
# 0      00601  18.18005  -66.75218    Adjuntas       PR  Puerto Rico  True
# 1      00602  18.36074  -67.17519      Aguada       PR  Puerto Rico  True
# 2      00603  18.45440  -67.12201   Aguadilla       PR  Puerto Rico  True
# 3      00606  18.16721  -66.93828     Maricao       PR  Puerto Rico  True
# 4      00610  18.29032  -67.12244      Anasco       PR  Puerto Rico  True
# ...      ...       ...        ...         ...      ...          ...   ...
# 33114  99922  55.30211 -133.03248    Hydaburg       AK       Alaska  True
# 33115  99923  55.97796 -130.03671       Hyder       AK       Alaska  True
# 33116  99925  55.55796 -132.97482     Klawock       AK       Alaska  True
# 33117  99926  55.12617 -131.48928  Metlakatla       AK       Alaska  True
# 33119  99929  56.36950 -131.93648    Wrangell       AK       Alaska  True
#
#        parent_zcta  population  density  county_fips            county_name  \
# 0              NaN     17113.0    102.7        72001               Adjuntas
# 1              NaN     37751.0    476.0        72003                 Aguada
# 2              NaN     47081.0    574.9        72005              Aguadilla
# 3              NaN      6392.0     58.3        72093                Maricao
# 4              NaN     26686.0    286.9        72011                 Añasco
# ...            ...         ...      ...          ...                    ...
# 33114          NaN       342.0      1.1         2198  Prince of Wales-Hyder
# 33115          NaN        14.0      0.3         2198  Prince of Wales-Hyder
# 33116          NaN       908.0      6.3         2198  Prince of Wales-Hyder
# 33117          NaN      1654.0      4.8         2198  Prince of Wales-Hyder
# 33119          NaN      2502.0      0.4         2275               Wrangell
#
#                                           county_weights  \
# 0                    {"72001": "99.43", "72141": "0.57"}
# 1                                       {"72003": "100"}
# 2                                       {"72005": "100"}
# 3      {"72093": "94.88", "72153": "3.78", "72121": "...
# 4                    {"72011": "99.45", "72003": "0.55"}
# ...                                                  ...
# 33114                                   {"02198": "100"}
# 33115                                   {"02198": "100"}
# 33116                                   {"02198": "100"}
# 33117                                   {"02198": "100"}
# 33119                                   {"02275": "100"}
#
#                   county_names_all    county_fips_all  imprecise  military  \
# 0                  Adjuntas|Utuado        72001|72141      False     False
# 1                           Aguada              72003      False     False
# 2                        Aguadilla              72005      False     False
# 3      Maricao|Yauco|Sabana Grande  72093|72153|72121      False     False
# 4                    Añasco|Aguada        72011|72003      False     False
# ...                            ...                ...        ...       ...
# 33114        Prince of Wales-Hyder              02198      False     False
# 33115        Prince of Wales-Hyder              02198      False     False
# 33116        Prince of Wales-Hyder              02198      False     False
# 33117        Prince of Wales-Hyder              02198      False     False
# 33119                     Wrangell              02275      False     False
#
#                   timezone
# 0      America/Puerto_Rico
# 1      America/Puerto_Rico
# 2      America/Puerto_Rico
# 3      America/Puerto_Rico
# 4      America/Puerto_Rico
# ...                    ...
# 33114        America/Sitka
# 33115        America/Sitka
# 33116        America/Sitka
# 33117   America/Metlakatla
# 33119        America/Sitka
#
# [32782 rows x 18 columns]

# %%
# Rename zip column
zip_data_df.rename(columns={'zip': 'zipcode'}, inplace=True)
zip_data_df
# Out:
#       zipcode       lat        lng        city state_id   state_name  zcta  \
# 0       00601  18.18005  -66.75218    Adjuntas       PR  Puerto Rico  True
# 1       00602  18.36074  -67.17519      Aguada       PR  Puerto Rico  True
# 2       00603  18.45440  -67.12201   Aguadilla       PR  Puerto Rico  True
# 3       00606  18.16721  -66.93828     Maricao       PR  Puerto Rico  True
# 4       00610  18.29032  -67.12244      Anasco       PR  Puerto Rico  True
# ...       ...       ...        ...         ...      ...          ...   ...
# 33114   99922  55.30211 -133.03248    Hydaburg       AK       Alaska  True
# 33115   99923  55.97796 -130.03671       Hyder       AK       Alaska  True
# 33116   99925  55.55796 -132.97482     Klawock       AK       Alaska  True
# 33117   99926  55.12617 -131.48928  Metlakatla       AK       Alaska  True
# 33119   99929  56.36950 -131.93648    Wrangell       AK       Alaska  True
#
#        parent_zcta  population  density  county_fips            county_name  \
# 0              NaN     17113.0    102.7        72001               Adjuntas
# 1              NaN     37751.0    476.0        72003                 Aguada
# 2              NaN     47081.0    574.9        72005              Aguadilla
# 3              NaN      6392.0     58.3        72093                Maricao
# 4              NaN     26686.0    286.9        72011                 Añasco
# ...            ...         ...      ...          ...                    ...
# 33114          NaN       342.0      1.1         2198  Prince of Wales-Hyder
# 33115          NaN        14.0      0.3         2198  Prince of Wales-Hyder
# 33116          NaN       908.0      6.3         2198  Prince of Wales-Hyder
# 33117          NaN      1654.0      4.8         2198  Prince of Wales-Hyder
# 33119          NaN      2502.0      0.4         2275               Wrangell
#
#                                           county_weights  \
# 0                    {"72001": "99.43", "72141": "0.57"}
# 1                                       {"72003": "100"}
# 2                                       {"72005": "100"}
# 3      {"72093": "94.88", "72153": "3.78", "72121": "...
# 4                    {"72011": "99.45", "72003": "0.55"}
# ...                                                  ...
# 33114                                   {"02198": "100"}
# 33115                                   {"02198": "100"}
# 33116                                   {"02198": "100"}
# 33117                                   {"02198": "100"}
# 33119                                   {"02275": "100"}
#
#                   county_names_all    county_fips_all  imprecise  military  \
# 0                  Adjuntas|Utuado        72001|72141      False     False
# 1                           Aguada              72003      False     False
# 2                        Aguadilla              72005      False     False
# 3      Maricao|Yauco|Sabana Grande  72093|72153|72121      False     False
# 4                    Añasco|Aguada        72011|72003      False     False
# ...                            ...                ...        ...       ...
# 33114        Prince of Wales-Hyder              02198      False     False
# 33115        Prince of Wales-Hyder              02198      False     False
# 33116        Prince of Wales-Hyder              02198      False     False
# 33117        Prince of Wales-Hyder              02198      False     False
# 33119                     Wrangell              02275      False     False
#
#                   timezone
# 0      America/Puerto_Rico
# 1      America/Puerto_Rico
# 2      America/Puerto_Rico
# 3      America/Puerto_Rico
# 4      America/Puerto_Rico
# ...                    ...
# 33114        America/Sitka
# 33115        America/Sitka
# 33116        America/Sitka
# 33117   America/Metlakatla
# 33119        America/Sitka
#
# [32782 rows x 18 columns]

# %%
# Drop columns
zip_data_df.drop(columns=["lat", "lng", "state_id", "state_name", "city", "parent_zcta", "population", "county_name", "density", "county_fips", "county_weights", 
                          "county_names_all", "county_fips_all", "imprecise", "military", "timezone"])
# Out:
#       zipcode  zcta
# 0       00601  True
# 1       00602  True
# 2       00603  True
# 3       00606  True
# 4       00610  True
# ...       ...   ...
# 33114   99922  True
# 33115   99923  True
# 33116   99925  True
# 33117   99926  True
# 33119   99929  True
#
# [32782 rows x 2 columns]

# %%
zip_data_df
# Out:
#       zipcode       lat        lng        city state_id   state_name  zcta  \
# 0       00601  18.18005  -66.75218    Adjuntas       PR  Puerto Rico  True
# 1       00602  18.36074  -67.17519      Aguada       PR  Puerto Rico  True
# 2       00603  18.45440  -67.12201   Aguadilla       PR  Puerto Rico  True
# 3       00606  18.16721  -66.93828     Maricao       PR  Puerto Rico  True
# 4       00610  18.29032  -67.12244      Anasco       PR  Puerto Rico  True
# ...       ...       ...        ...         ...      ...          ...   ...
# 33114   99922  55.30211 -133.03248    Hydaburg       AK       Alaska  True
# 33115   99923  55.97796 -130.03671       Hyder       AK       Alaska  True
# 33116   99925  55.55796 -132.97482     Klawock       AK       Alaska  True
# 33117   99926  55.12617 -131.48928  Metlakatla       AK       Alaska  True
# 33119   99929  56.36950 -131.93648    Wrangell       AK       Alaska  True
#
#        parent_zcta  population  density  county_fips            county_name  \
# 0              NaN     17113.0    102.7        72001               Adjuntas
# 1              NaN     37751.0    476.0        72003                 Aguada
# 2              NaN     47081.0    574.9        72005              Aguadilla
# 3              NaN      6392.0     58.3        72093                Maricao
# 4              NaN     26686.0    286.9        72011                 Añasco
# ...            ...         ...      ...          ...                    ...
# 33114          NaN       342.0      1.1         2198  Prince of Wales-Hyder
# 33115          NaN        14.0      0.3         2198  Prince of Wales-Hyder
# 33116          NaN       908.0      6.3         2198  Prince of Wales-Hyder
# 33117          NaN      1654.0      4.8         2198  Prince of Wales-Hyder
# 33119          NaN      2502.0      0.4         2275               Wrangell
#
#                                           county_weights  \
# 0                    {"72001": "99.43", "72141": "0.57"}
# 1                                       {"72003": "100"}
# 2                                       {"72005": "100"}
# 3      {"72093": "94.88", "72153": "3.78", "72121": "...
# 4                    {"72011": "99.45", "72003": "0.55"}
# ...                                                  ...
# 33114                                   {"02198": "100"}
# 33115                                   {"02198": "100"}
# 33116                                   {"02198": "100"}
# 33117                                   {"02198": "100"}
# 33119                                   {"02275": "100"}
#
#                   county_names_all    county_fips_all  imprecise  military  \
# 0                  Adjuntas|Utuado        72001|72141      False     False
# 1                           Aguada              72003      False     False
# 2                        Aguadilla              72005      False     False
# 3      Maricao|Yauco|Sabana Grande  72093|72153|72121      False     False
# 4                    Añasco|Aguada        72011|72003      False     False
# ...                            ...                ...        ...       ...
# 33114        Prince of Wales-Hyder              02198      False     False
# 33115        Prince of Wales-Hyder              02198      False     False
# 33116        Prince of Wales-Hyder              02198      False     False
# 33117        Prince of Wales-Hyder              02198      False     False
# 33119                     Wrangell              02275      False     False
#
#                   timezone
# 0      America/Puerto_Rico
# 1      America/Puerto_Rico
# 2      America/Puerto_Rico
# 3      America/Puerto_Rico
# 4      America/Puerto_Rico
# ...                    ...
# 33114        America/Sitka
# 33115        America/Sitka
# 33116        America/Sitka
# 33117   America/Metlakatla
# 33119        America/Sitka
#
# [32782 rows x 18 columns]

# %%
# NOTE: MODIFIED FROM JENNY'S FILE.  ORIGINAL CODE IS TWO CELLS ABOVE.

# Drop columns
zip_data_df = zip_data_df.drop(columns=["lat", "lng", "state_id", "state_name", "city", "parent_zcta", "population", "county_name", "density", "county_fips", "county_weights", 
                          "county_names_all", "county_fips_all", "imprecise", "military", "timezone"])

# %%
# NOTE: MODIFIED FROM JENNY'S FILE.  ADDITIONAL DISPLAY AFTER CHANGES MADE TO DF.

zip_data_df
# Out:
#       zipcode  zcta
# 0       00601  True
# 1       00602  True
# 2       00603  True
# 3       00606  True
# 4       00610  True
# ...       ...   ...
# 33114   99922  True
# 33115   99923  True
# 33116   99925  True
# 33117   99926  True
# 33119   99929  True
#
# [32782 rows x 2 columns]

# %%
# NOTE: MODIFIED FROM JENNY'S FILE.  COMMENTED OUT.

# Output to CSV
# zip_data_df.to_csv("Resources/zipcodes.csv")

# %% [markdown]
# ### Use "normalize_zip" function in "zip_data_df" to ensure that all zip codes have 5 digits
# #### Left in as placeholder in case needed later

# %%
# zip_data_df.dtypes

# %%
# zipcode_s = zip_data_df["zipcode"]
# zipcode_s

# %%
# zipcode_len = zipcode_s.map(len)
# zipcode_len

# %%
# zipcode_len.value_counts()

# %%
# zipcode_s = zip_data_df["zipcode"]
# zipcode_s

# %%
# zip_five_s = zipcode_s.map(first_five)
# zip_five_s

# %%
# zip_data_df["zipcode"] = zip_five_s
# zip_data_df

# %%
# zipcode_len = zipcode_s.map(len)
# zipcode_len

# %%
# zipcode_len.value_counts()

# %% [markdown]
# ### Additional steps for Rev 04 to filter by Michigan

# %%
# Filter by state of Michigan only
# NOTE: NEEDED FOR THIS DATAFRAME?  IF SO, NEEDS TO BE INPUT BEFORE DROPPING state_id COLUMN

# %% [markdown]
# ### Merge Dataframes

# %%
#1
merged_df = income_original_df.merge(physicians_original_df, left_on="zipcode", right_on="zip")
merged_df

# NOTE: CHOOSE DIFFERENT MERGE OPTIONS?
# Out:
#       state zipcode  total_pop  total_income     avg_income         npi  \
# 0        MI   48001       6270        385108   61420.733652  1457637506
# 1        MI   48001       6270        385108   61420.733652  1043201767
# 2        MI   48001       6270        385108   61420.733652  1578008025
# 3        MI   48001       6270        385108   61420.733652  1699766030
# 4        MI   48001       6270        385108   61420.733652  1902897689
# ...     ...     ...        ...           ...            ...         ...
# 40074    MI   49969        590        132776  225044.067797  1407851413
# 40075    MI   49969        590        132776  225044.067797  1376056135
# 40076    MI   49969        590        132776  225044.067797  1629115977
# 40077    MI   49969        590        132776  225044.067797  1811363690
# 40078    MI   49969        590        132776  225044.067797  1912372350
#
#       grd_yr             pri_spec         cty  st    zip ind_assgn grp_assgn
# 0       2011      FAMILY MEDICINE     ALGONAC  MI  48001         Y         M
# 1       1989      FAMILY MEDICINE     ALGONAC  MI  48001         Y         Y
# 2       2016   NURSE PRACTITIONER     ALGONAC  MI  48001         Y         Y
# 3       1995      FAMILY MEDICINE     ALGONAC  MI  48001         Y         Y
# 4       1986      FAMILY MEDICINE     ALGONAC  MI  48001         Y         Y
# ...      ...                  ...         ...  ..    ...       ...       ...
# 40074   1994    INTERNAL MEDICINE  WATERSMEET  MI  49969         Y         Y
# 40075   2017   NURSE PRACTITIONER  WATERSMEET  MI  49969         Y         Y
# 40076   2004      FAMILY MEDICINE  WATERSMEET  MI  49969         Y         Y
# 40077   2015  PHYSICIAN ASSISTANT  WATERSMEET  MI  49969         Y         Y
# 40078   2015   NURSE PRACTITIONER  WATERSMEET  MI  49969         Y         Y
#
# [40079 rows x 13 columns]

# %%
# NOTE: WHY HAS THE DATA BEEN FILTERED DOWN 101,695 (FROM 2,375,857 TO 2,274,162)?

# %%
# Check dtypes
merged_df.dtypes
# Out:
# state            object
# zipcode          object
# total_pop         int64
# total_income      int64
# avg_income      float64
# npi               int64
# grd_yr           object
# pri_spec         object
# cty              object
# st               object
# zip              object
# ind_assgn        object
# grp_assgn        object
# dtype: object

# %%
# Drop redundant columns
merged_df.drop(columns=["st", "zip"], inplace=True)
merged_df
# Out:
#       state zipcode  total_pop  total_income     avg_income         npi  \
# 0        MI   48001       6270        385108   61420.733652  1457637506
# 1        MI   48001       6270        385108   61420.733652  1043201767
# 2        MI   48001       6270        385108   61420.733652  1578008025
# 3        MI   48001       6270        385108   61420.733652  1699766030
# 4        MI   48001       6270        385108   61420.733652  1902897689
# ...     ...     ...        ...           ...            ...         ...
# 40074    MI   49969        590        132776  225044.067797  1407851413
# 40075    MI   49969        590        132776  225044.067797  1376056135
# 40076    MI   49969        590        132776  225044.067797  1629115977
# 40077    MI   49969        590        132776  225044.067797  1811363690
# 40078    MI   49969        590        132776  225044.067797  1912372350
#
#       grd_yr             pri_spec         cty ind_assgn grp_assgn
# 0       2011      FAMILY MEDICINE     ALGONAC         Y         M
# 1       1989      FAMILY MEDICINE     ALGONAC         Y         Y
# 2       2016   NURSE PRACTITIONER     ALGONAC         Y         Y
# 3       1995      FAMILY MEDICINE     ALGONAC         Y         Y
# 4       1986      FAMILY MEDICINE     ALGONAC         Y         Y
# ...      ...                  ...         ...       ...       ...
# 40074   1994    INTERNAL MEDICINE  WATERSMEET         Y         Y
# 40075   2017   NURSE PRACTITIONER  WATERSMEET         Y         Y
# 40076   2004      FAMILY MEDICINE  WATERSMEET         Y         Y
# 40077   2015  PHYSICIAN ASSISTANT  WATERSMEET         Y         Y
# 40078   2015   NURSE PRACTITIONER  WATERSMEET         Y         Y
#
# [40079 rows x 11 columns]

# %%
# Move zip code column to 1st column (not index).  Move city and state immediately after.
merged_df = merged_df[["zipcode", "cty", "state", "total_pop", "total_income", "avg_income", "npi", "grd_yr", "pri_spec", "ind_assgn", "grp_assgn"]]
merged_df
# Out:
#       zipcode         cty state  total_pop  total_income     avg_income  \
# 0       48001     ALGONAC    MI       6270        385108   61420.733652
# 1       48001     ALGONAC    MI       6270        385108   61420.733652
# 2       48001     ALGONAC    MI       6270        385108   61420.733652
# 3       48001     ALGONAC    MI       6270        385108   61420.733652
# 4       48001     ALGONAC    MI       6270        385108   61420.733652
# ...       ...         ...   ...        ...           ...            ...
# 40074   49969  WATERSMEET    MI        590        132776  225044.067797
# 40075   49969  WATERSMEET    MI        590        132776  225044.067797
# 40076   49969  WATERSMEET    MI        590        132776  225044.067797
# 40077   49969  WATERSMEET    MI        590        132776  225044.067797
# 40078   49969  WATERSMEET    MI        590        132776  225044.067797
#
#               npi grd_yr             pri_spec ind_assgn grp_assgn
# 0      1457637506   2011      FAMILY MEDICINE         Y         M
# 1      1043201767   1989      FAMILY MEDICINE         Y         Y
# 2      1578008025   2016   NURSE PRACTITIONER         Y         Y
# 3      1699766030   1995      FAMILY MEDICINE         Y         Y
# 4      1902897689   1986      FAMILY MEDICINE         Y         Y
# ...           ...    ...                  ...       ...       ...
# 40074  1407851413   1994    INTERNAL MEDICINE         Y         Y
# 40075  1376056135   2017   NURSE PRACTITIONER         Y         Y
# 40076  1629115977   2004      FAMILY MEDICINE         Y         Y
# 40077  1811363690   2015  PHYSICIAN ASSISTANT         Y         Y
# 40078  1912372350   2015   NURSE PRACTITIONER         Y         Y
#
# [40079 rows x 11 columns]

# %%
# merged_df["total_pop"] = pd.to_numeric(merged_df["total_pop"])

# %%
# Check dtypes
# merged_df.dtypes

# %%
# Find null values
for column in merged_df.columns:
    print(f"Column {column} has {merged_df[column].isnull().sum()} null values")
# Out:
# Column zipcode has 0 null values
# Column cty has 0 null values
# Column state has 0 null values
# Column total_pop has 0 null values
# Column total_income has 0 null values
# Column avg_income has 0 null values
# Column npi has 0 null values
# Column grd_yr has 25 null values
# Column pri_spec has 0 null values
# Column ind_assgn has 0 null values
# Column grp_assgn has 0 null values

# %%
# len(merged_df["zipcode"].unique())

# %%
# Add column calculating total number of doctors per zipcode
# Use transform with count?
merged_df["doctor_count"] = merged_df.groupby(["zipcode"])["zipcode"].transform("count")
merged_df
# Out:
# C:\Users\Tony\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       zipcode         cty state  total_pop  total_income     avg_income  \
# 0       48001     ALGONAC    MI       6270        385108   61420.733652
# 1       48001     ALGONAC    MI       6270        385108   61420.733652
# 2       48001     ALGONAC    MI       6270        385108   61420.733652
# 3       48001     ALGONAC    MI       6270        385108   61420.733652
# 4       48001     ALGONAC    MI       6270        385108   61420.733652
# ...       ...         ...   ...        ...           ...            ...
# 40074   49969  WATERSMEET    MI        590        132776  225044.067797
# 40075   49969  WATERSMEET    MI        590        132776  225044.067797
# 40076   49969  WATERSMEET    MI        590        132776  225044.067797
# 40077   49969  WATERSMEET    MI        590        132776  225044.067797
# 40078   49969  WATERSMEET    MI        590        132776  225044.067797
#
#               npi grd_yr             pri_spec ind_assgn grp_assgn  \
# 0      1457637506   2011      FAMILY MEDICINE         Y         M
# 1      1043201767   1989      FAMILY MEDICINE         Y         Y
# 2      1578008025   2016   NURSE PRACTITIONER         Y         Y
# 3      1699766030   1995      FAMILY MEDICINE         Y         Y
# 4      1902897689   1986      FAMILY MEDICINE         Y         Y
# ...           ...    ...                  ...       ...       ...
# 40074  1407851413   1994    INTERNAL MEDICINE         Y         Y
# 40075  1376056135   2017   NURSE PRACTITIONER         Y         Y
# 40076  1629115977   2004      FAMILY MEDICINE         Y         Y
# 40077  1811363690   2015  PHYSICIAN ASSISTANT         Y         Y
# 40078  1912372350   2015   NURSE PRACTITIONER         Y         Y
#
#        doctor_count
# 0                 5
# 1                 5
# 2                 5
# 3                 5
# 4                 5
# ...             ...
# 40074             6
# 40075             6
# 40076             6
# 40077             6
# 40078             6
#
# [40079 rows x 12 columns]

# %%
# Add column calculating avg_income per # of doctors
merged_df["pcp_per_capita"] = merged_df["doctor_count"]/merged_df["total_pop"]
merged_df
# Out:
# C:\Users\Tony\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       zipcode         cty state  total_pop  total_income     avg_income  \
# 0       48001     ALGONAC    MI       6270        385108   61420.733652
# 1       48001     ALGONAC    MI       6270        385108   61420.733652
# 2       48001     ALGONAC    MI       6270        385108   61420.733652
# 3       48001     ALGONAC    MI       6270        385108   61420.733652
# 4       48001     ALGONAC    MI       6270        385108   61420.733652
# ...       ...         ...   ...        ...           ...            ...
# 40074   49969  WATERSMEET    MI        590        132776  225044.067797
# 40075   49969  WATERSMEET    MI        590        132776  225044.067797
# 40076   49969  WATERSMEET    MI        590        132776  225044.067797
# 40077   49969  WATERSMEET    MI        590        132776  225044.067797
# 40078   49969  WATERSMEET    MI        590        132776  225044.067797
#
#               npi grd_yr             pri_spec ind_assgn grp_assgn  \
# 0      1457637506   2011      FAMILY MEDICINE         Y         M
# 1      1043201767   1989      FAMILY MEDICINE         Y         Y
# 2      1578008025   2016   NURSE PRACTITIONER         Y         Y
# 3      1699766030   1995      FAMILY MEDICINE         Y         Y
# 4      1902897689   1986      FAMILY MEDICINE         Y         Y
# ...           ...    ...                  ...       ...       ...
# 40074  1407851413   1994    INTERNAL MEDICINE         Y         Y
# 40075  1376056135   2017   NURSE PRACTITIONER         Y         Y
# 40076  1629115977   2004      FAMILY MEDICINE         Y         Y
# 40077  1811363690   2015  PHYSICIAN ASSISTANT         Y         Y
# 40078  1912372350   2015   NURSE PRACTITIONER         Y         Y
#
#        doctor_count  pcp_per_capita
# 0                 5        0.000797
# 1                 5        0.000797
# 2                 5        0.000797
# 3                 5        0.000797
# 4                 5        0.000797
# ...             ...             ...
# 40074             6        0.010169
# 40075             6        0.010169
# 40076             6        0.010169
# 40077             6        0.010169
# 40078             6        0.010169
#
# [40079 rows x 13 columns]

# %%
# Review calculated info in new pcp_per_capita column
merged_df.pcp_per_capita.describe()
# Out:
# count    40079.000000
# mean         3.466516
# std          8.396947
# min          0.000149
# 25%          0.008753
# 50%          0.020898
# 75%          0.055357
# max         23.975000
# Name: pcp_per_capita, dtype: float64

# %%
# Check dtypes
merged_df.dtypes
# Out:
# zipcode            object
# cty                object
# state              object
# total_pop           int64
# total_income        int64
# avg_income        float64
# npi                 int64
# grd_yr             object
# pri_spec           object
# ind_assgn          object
# grp_assgn          object
# doctor_count        int64
# pcp_per_capita    float64
# dtype: object

# %%
# Format columns
# merged_df["total_pop"] = merged_df["total_pop"].map("{:,}".format)
merged_df["total_income"] = merged_df["total_income"].map("${:,.0f}".format)
merged_df["avg_income"] = merged_df["avg_income"].map("${:,.0f}".format)
merged_df
# Out:
# C:\Users\Tony\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Tony\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#       zipcode         cty state  total_pop total_income avg_income  \
# 0       48001     ALGONAC    MI       6270     $385,108    $61,421
# 1       48001     ALGONAC    MI       6270     $385,108    $61,421
# 2       48001     ALGONAC    MI       6270     $385,108    $61,421
# 3       48001     ALGONAC    MI       6270     $385,108    $61,421
# 4       48001     ALGONAC    MI       6270     $385,108    $61,421
# ...       ...         ...   ...        ...          ...        ...
# 40074   49969  WATERSMEET    MI        590     $132,776   $225,044
# 40075   49969  WATERSMEET    MI        590     $132,776   $225,044
# 40076   49969  WATERSMEET    MI        590     $132,776   $225,044
# 40077   49969  WATERSMEET    MI        590     $132,776   $225,044
# 40078   49969  WATERSMEET    MI        590     $132,776   $225,044
#
#               npi grd_yr             pri_spec ind_assgn grp_assgn  \
# 0      1457637506   2011      FAMILY MEDICINE         Y         M
# 1      1043201767   1989      FAMILY MEDICINE         Y         Y
# 2      1578008025   2016   NURSE PRACTITIONER         Y         Y
# 3      1699766030   1995      FAMILY MEDICINE         Y         Y
# 4      1902897689   1986      FAMILY MEDICINE         Y         Y
# ...           ...    ...                  ...       ...       ...
# 40074  1407851413   1994    INTERNAL MEDICINE         Y         Y
# 40075  1376056135   2017   NURSE PRACTITIONER         Y         Y
# 40076  1629115977   2004      FAMILY MEDICINE         Y         Y
# 40077  1811363690   2015  PHYSICIAN ASSISTANT         Y         Y
# 40078  1912372350   2015   NURSE PRACTITIONER         Y         Y
#
#        doctor_count  pcp_per_capita
# 0                 5        0.000797
# 1                 5        0.000797
# 2                 5        0.000797
# 3                 5        0.000797
# 4                 5        0.000797
# ...             ...             ...
# 40074             6        0.010169
# 40075             6        0.010169
# 40076             6        0.010169
# 40077             6        0.010169
# 40078             6        0.010169
#
# [40079 rows x 13 columns]

# %% [markdown]
# ### Add additional merge for zcta

# %%
# Merge to zcta
final_merge_df = merged_df.merge(zip_data_df, left_on="zipcode", right_on="zipcode")
final_merge_df
# Out:
#       zipcode         cty state  total_pop total_income avg_income  \
# 0       48001     ALGONAC    MI       6270     $385,108    $61,421
# 1       48001     ALGONAC    MI       6270     $385,108    $61,421
# 2       48001     ALGONAC    MI       6270     $385,108    $61,421
# 3       48001     ALGONAC    MI       6270     $385,108    $61,421
# 4       48001     ALGONAC    MI       6270     $385,108    $61,421
# ...       ...         ...   ...        ...          ...        ...
# 40074   49969  WATERSMEET    MI        590     $132,776   $225,044
# 40075   49969  WATERSMEET    MI        590     $132,776   $225,044
# 40076   49969  WATERSMEET    MI        590     $132,776   $225,044
# 40077   49969  WATERSMEET    MI        590     $132,776   $225,044
# 40078   49969  WATERSMEET    MI        590     $132,776   $225,044
#
#               npi grd_yr             pri_spec ind_assgn grp_assgn  \
# 0      1457637506   2011      FAMILY MEDICINE         Y         M
# 1      1043201767   1989      FAMILY MEDICINE         Y         Y
# 2      1578008025   2016   NURSE PRACTITIONER         Y         Y
# 3      1699766030   1995      FAMILY MEDICINE         Y         Y
# 4      1902897689   1986      FAMILY MEDICINE         Y         Y
# ...           ...    ...                  ...       ...       ...
# 40074  1407851413   1994    INTERNAL MEDICINE         Y         Y
# 40075  1376056135   2017   NURSE PRACTITIONER         Y         Y
# 40076  1629115977   2004      FAMILY MEDICINE         Y         Y
# 40077  1811363690   2015  PHYSICIAN ASSISTANT         Y         Y
# 40078  1912372350   2015   NURSE PRACTITIONER         Y         Y
#
#        doctor_count  pcp_per_capita  zcta
# 0                 5        0.000797  True
# 1                 5        0.000797  True
# 2                 5        0.000797  True
# 3                 5        0.000797  True
# 4                 5        0.000797  True
# ...             ...             ...   ...
# 40074             6        0.010169  True
# 40075             6        0.010169  True
# 40076             6        0.010169  True
# 40077             6        0.010169  True
# 40078             6        0.010169  True
#
# [40079 rows x 14 columns]

# %% [markdown]
# ### Add additional merge for county

# %%
# Merge to county
final_merge_df2 = final_merge_df.merge(zip_county_merge_df, left_on="zipcode", right_on="zip")
final_merge_df2
# Out:
# Empty DataFrame
# Columns: [zipcode, cty, state_x, total_pop, total_income, avg_income, npi, grd_yr, pri_spec, ind_assgn, grp_assgn, doctor_count, pcp_per_capita, zcta, GeoFips, county, state_y, population, per_capita_income, zip, latitude, longitude]
# Index: []
#
# [0 rows x 22 columns]

# %%
# Saving file as reference
final_merge_df.to_csv("Resources/final_merge_df.csv")
